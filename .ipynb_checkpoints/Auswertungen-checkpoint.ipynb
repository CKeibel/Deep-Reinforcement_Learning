# %% [markdown]
# # Auswertung

# %% [markdown]
# ## Deep Q-Learning

# %% [markdown]
# ### Pong-v0

# %%
import matplotlib.pyplot as plt
import pandas as pd

path = "Deep Q-Network/Results/Pong/DQN_Pong-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### Breakout-v0

# %%
path = "Deep Q-Network/Results/Breakout-v0/Breakout-v0_2021-03-28_NoEpisodicLife_NoClipReward.csv"
results = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e356ed88048b> in <module>
#       1 path = "Deep Q-Network/Results/Breakout-v0/Breakout-v0_2021-03-28_NoEpisodicLife_NoClipReward.csv"
# ----> 2 results = pd.read_csv(path)
#
# ...

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### MsPacman-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Advantage Actor Critic (A2C)

# %% [markdown]
# ### Pong-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### Breakout-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### MsPacman-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Proximal Policy Optimization (PPO)

# %% [markdown]
# ### Pong-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### Breakout-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### MsPacman-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()
