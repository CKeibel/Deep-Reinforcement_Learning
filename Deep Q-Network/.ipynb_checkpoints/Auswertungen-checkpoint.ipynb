# %% [markdown]
# # Auswertung

# %% [markdown]
# ## Deep Q-Learning

# %% [markdown]
# ### Pong-v0

# %%
import matplotlib.pyplot as plt
import pandas as pd

path = "Deep Q-Network/Results/Pong/DQN_Pong-v0_Auswertung.csv"
results = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-402ae7863e69> in <module>
#       3
#       4 path = "Deep Q-Network/Results/Pong/DQN_Pong-v0_Auswertung.csv"
# ----> 5 results = pd.read_csv(path)
#
# D:\Programme\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# D:\Programme\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# D:\Programme\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# D:\Programme\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# D:\Programme\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Deep Q-Network/Results/Pong/DQN_Pong-v0_Auswertung.csv'

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### Breakout-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_Breakout-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### MsPacman-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Advantage Actor Critic (A2C)

# %% [markdown]
# ### Pong-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### Breakout-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### MsPacman-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Proximal Policy Optimization (PPO)

# %% [markdown]
# ### Pong-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### Breakout-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### MsPacman-v0

# %%
path = "Deep Q-Network/Auswertung/DQN_MsPacman-v0_Auswertung.csv"
results = pd.read_csv(path)

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=range(0, results['Rewards'].size), y=results['Rewards'], s=3, color="cadetblue", label="Rewards")
plt.plot(results['Mean Reward'], color="red", label="Mean Reward", linewidth=3)
plt.xlabel("Episoden", fontsize=20)
plt.ylabel("Rewards", fontsize=20)
plt.legend()
plt.show()
